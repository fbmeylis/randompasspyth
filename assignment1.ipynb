# %%
#Q1
# !pip install names
import names
x= []
for i in range(10):
  x.append(names.get_full_name())
  print(x[i])

x.sort()
print("New Sorted")
for i in range(10):
  print(x[i])
  print(len(x[i]))

sorted(x,key=len)

# %%
#Q2
import string
characters = list(string.ascii_lowercase + string.digits)
length = int(input("Enter password length: "))
if length<11 and length>3:
  import random
  random.shuffle(characters)
  password = []
  for i in range(length):
  	password.append(random.choice(characters))
  random.shuffle(password)  
  print(password)
else:
  print("Please import number between 4 and 10")
# Out:
# Enter password length: 5
# ['8', 'p', 'i', 'r', 'x']

# %%
#Q3
import random
thistuple=[]
y=-100
for y in range(301):
  thistuple.append(y-100)

randi=[]
for x in range(30):
  randi.append(random.randint(-100,200))
  print(randi[x])


D = []

for z in range(0,30,2):
  if randi[z]>randi[z+1]:
    D.append(randi[z]-randi[z+1])
  elif randi[z+1]>randi[z]:
    D.append(randi[z+1]-randi[z])
    
  
tuple(D)
# Out:
# 12
# 1
# -5
# -88
# 55
# 165
# 63
# 6
# -86
# 156
# 96
# 172
# 13
# 138
# -47
# 120
# 118
# 53
# 198
# 170
# -48
# 74
# 159
# 121
# -72
# 173
# 38
# -79
# -33
# -87
# (11, 83, 110, 57, 242, 76, 125, 167, 65, 28, 122, 38, 245, 117, 54)
